# %% [markdown]
# ### DataFrame and Series

# %%
import pandas as pd

# %% [markdown]
# Create a simple Pandas Series from a dictionary

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# Create a simple Pandas DataFrame

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
data_F = pd.DataFrame(data)

print( data_F)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#Add a list of names to give each row a name:
data_F = pd.DataFrame(data , index = ["day_1" , "day_2" , "day_3"])
data_F
# Out:
#        calories  duration
# day_1       420        50
# day_2       380        40
# day_3       390        45

# %% [markdown]
# Load Data pd.read_csv()

# %%
df = pd.read_csv("HRDataset_v14.csv")

# %% [markdown]
# ##### Get shape: df.shape

# %%
df.shape
# Out:
# (311, 36)

# %% [markdown]
# ##### pandas.DataFrame.size

# %%
#Return an int representing the number of elements in object.
df.size
# Out:
# 11196

# %% [markdown]
# ##### Get First Rows: df.head()

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# ##### Get last Rows: df.tail()

# %%
df.tail(7)
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 304  Winthrop, Jordan    10033          0                0         1
# 305       Wolk, Hang  T  10174          0                0         0
# 306      Woodson, Jason  10135          0                0         1
# 307  Ybarra, Catherine   10301          0                0         0
# 308    Zamora, Jennifer  10010          0                0         0
# 309         Zhou, Julia  10043          0                0         0
# 310       Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 304            5       5            4                       0   70507  ...
# 305            1       5            3                       0   60446  ...
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# ...

# %% [markdown]
# ##### Get Summarizing Statistics: df.info() & df.describe()

# %%
# method prints information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
pd.set_option('display.max_columns' , 36)

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
#Get Number of columns in DataFrame
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
#Get Number of Rows in DataFrame
df.index
# Out:
# RangeIndex(start=0, stop=311, step=1)

# %% [markdown]
# Extract a Single Column: df['col_name']

# %%
df.GenderID
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 306    1
# 307    0
# 308    0
# 309    0
# 310    0
# Name: GenderID, Length: 311, dtype: int64

# %%
df.GenderID.value_counts()
# Out:
# 0    176
# 1    135
# Name: GenderID, dtype: int64

# %%
df["GenderID"]
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 306    1
# 307    0
# 308    0
# 309    0
# 310    0
# Name: GenderID, Length: 311, dtype: int64

# %% [markdown]
# Extract N Columns: df[['col1_name', 'col2_name']]

# %%
df[["GenderID" , "PositionID" , "RecruitmentSource"]]
# Out:
#      GenderID  PositionID  RecruitmentSource
# 0           1          19           LinkedIn
# 1           1          27             Indeed
# 2           0          20           LinkedIn
# 3           0          19             Indeed
# 4           0          19      Google Search
# ..        ...         ...                ...
# 306         1          20           LinkedIn
# 307         0          19      Google Search
# 308         0           6  Employee Referral
# 309         0           9  Employee Referral
# 310         0          19           LinkedIn
#
# [311 rows x 3 columns]

# %% [markdown]
# ##### Extract Multiple Rows and Columns

# %%
#loc is used to select data by label
df.loc[ : ,"GenderID"]
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 306    1
# 307    0
# 308    0
# 309    0
# 310    0
# Name: GenderID, Length: 311, dtype: int64

# %%
# use to select a specific row or column from the data set  {integer location}
#sclicing with columns & rows
df.iloc[5 : , : 8]
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 5     Anderson, Linda    10002          0                0         0
# 6       Andreola, Colby  10194          0                0         0
# 7           Athwal, Sam  10062          0                4         1
# 8      Bachiochi, Linda  10114          0                0         0
# 9    Bacong, Alejandro   10250          0                2         1
# ..                  ...    ...        ...              ...       ...
# 306      Woodson, Jason  10135          0                0         1
# 307  Ybarra, Catherine   10301          0                0         0
# 308    Zamora, Jennifer  10010          0                0         0
# 309         Zhou, Julia  10043          0                0         0
# 310       Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID
# 5              1       5            4
# 6              1       4            3
# ...

# %%
df.loc[[1,2] ,["EmpID" ,"MarriedID"]]
# Out:
#    EmpID  MarriedID
# 1  10084          1
# 2  10196          1

# %%
df.iloc[[1,2] , [1,2]]
# Out:
#    EmpID  MarriedID
# 1  10084          1
# 2  10196          1

# %% [markdown]
# ##### Extract Rows using Boolean Subsetting

# %%
df.loc[df["DeptID"]==5 , :]
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi, Wilson  K  10026          0                0         1
# 2      Akinkuolie, Sarah  10196          1                1         0
# 3           Alagbe,Trina  10088          1                1         0
# 4       Anderson, Carol   10069          0                2         0
# 5      Anderson, Linda    10002          0                0         0
# ..                   ...    ...        ...              ...       ...
# 304   Winthrop, Jordan    10033          0                0         1
# 305        Wolk, Hang  T  10174          0                0         0
# 306       Woodson, Jason  10135          0                0         1
# 307   Ybarra, Catherine   10301          0                0         0
# 310        Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# ...

# %% [markdown]
# ##### pandas.DataFrame.set_index

# %%
#Set the DataFrame index using existing columns.
df.set_index("EmpID")
# Out:
#                   Employee_Name  MarriedID  MaritalStatusID  GenderID  \
# EmpID
# 10026       Adinolfi, Wilson  K          0                0         1
# 10084  Ait Sidi, Karthikeyan             1                1         1
# 10196         Akinkuolie, Sarah          1                1         0
# 10088              Alagbe,Trina          1                1         0
# 10069          Anderson, Carol           0                2         0
# ...                         ...        ...              ...       ...
# 10135            Woodson, Jason          0                0         1
# 10301        Ybarra, Catherine           0                0         0
# 10010          Zamora, Jennifer          0                0         0
# 10043               Zhou, Julia          0                0         0
# 10271             Zima, Colleen          0                4         0
#
#        EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  \
# EmpID
# ...

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
#Create a MultiIndex using columns
df.set_index(["DeptID","Employee_Name"])
# Out:
#                                  EmpID  MarriedID  MaritalStatusID  GenderID  \
# DeptID Employee_Name
# 5      Adinolfi, Wilson  K       10026          0                0         1
# 3      Ait Sidi, Karthikeyan     10084          1                1         1
# 5      Akinkuolie, Sarah         10196          1                1         0
#        Alagbe,Trina              10088          1                1         0
#        Anderson, Carol           10069          0                2         0
# ...                                ...        ...              ...       ...
#        Woodson, Jason            10135          0                0         1
#        Ybarra, Catherine         10301          0                0         0
# 3      Zamora, Jennifer          10010          0                0         0
#        Zhou, Julia               10043          0                0         0
# 5      Zima, Colleen             10271          0                4         0
#
# ...

# %%
df.reset_index()
# Out:
#      index             Employee_Name  EmpID  MarriedID  MaritalStatusID  \
# 0        0       Adinolfi, Wilson  K  10026          0                0
# 1        1  Ait Sidi, Karthikeyan     10084          1                1
# 2        2         Akinkuolie, Sarah  10196          1                1
# 3        3              Alagbe,Trina  10088          1                1
# 4        4          Anderson, Carol   10069          0                2
# ..     ...                       ...    ...        ...              ...
# 306    306            Woodson, Jason  10135          0                0
# 307    307        Ybarra, Catherine   10301          0                0
# 308    308          Zamora, Jennifer  10010          0                0
# 309    309               Zhou, Julia  10043          0                0
# 310    310             Zima, Colleen  10271          0                4
#
#      GenderID  EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  \
# ...

# %% [markdown]
# ##### filtering - using conditions to filter rows and columns

# %%
FilterOne = df["EmploymentStatus"]=="Active"

# %%
FilterOne
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 306     True
# 307    False
# 308     True
# 309     True
# 310     True
# Name: EmploymentStatus, Length: 311, dtype: bool

# %%
df[ df["EmploymentStatus"]=="Active"]
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi, Wilson  K  10026          0                0         1
# 3           Alagbe,Trina  10088          1                1         0
# 5      Anderson, Linda    10002          0                0         0
# 6        Andreola, Colby  10194          0                0         0
# 7            Athwal, Sam  10062          0                4         1
# ..                   ...    ...        ...              ...       ...
# 305        Wolk, Hang  T  10174          0                0         0
# 306       Woodson, Jason  10135          0                0         1
# 308     Zamora, Jennifer  10010          0                0         0
# 309          Zhou, Julia  10043          0                0         0
# 310        Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# ...

# %%
#show a specific column value for a filter value by using loc
df.loc[ df["EmploymentStatus"]=="Active" ,"Salary" ]
# Out:
# 0       62506
# 3       64991
# 5       57568
# 6       95660
# 7       59365
#         ...
# 305     60446
# 306     65893
# 308    220450
# 309     89292
# 310     45046
# Name: Salary, Length: 207, dtype: int64

# %%
 #filter using "or"(|) , "and"(&)
FilterTwo = ((df["EmploymentStatus"]=="Active") & (df["Position"]=="Data Analyst")) 
df[FilterTwo]
# Out:
#          Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 12    Barbossa, Hector  10012          0                2         1
# 57     Costello, Frank  10193          1                1         1
# 220  Petrowsky, Thelma  10016          1                1         0
# 238        Roby, Lori   10162          1                1         0
# 254     Simard, Kramer  10178          1                1         1
# 309        Zhou, Julia  10043          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 12             1       3            4                       1   92328      0
# 57             1       3            3                       0   83552      0
# 220            1       3            4                       0   93554      0
# 238            1       3            3                       0   89883      0
# 254            1       3            3                       0   87826      0
# ...

# %% [markdown]
# ### Updating Data

# %%
df.rename(columns = {"Employee_Name" : "Names"} , inplace=True)
df
# Out:
#                         Names  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df.columns = df.columns.str.replace("EmpID", "MaimID")
df
# Out:
#                         Names  MaimID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K   10026          0                0         1
# 1    Ait Sidi, Karthikeyan      10084          1                1         1
# 2           Akinkuolie, Sarah   10196          1                1         0
# 3                Alagbe,Trina   10088          1                1         0
# 4            Anderson, Carol    10069          0                2         0
# ..                        ...     ...        ...              ...       ...
# 306            Woodson, Jason   10135          0                0         1
# 307        Ybarra, Catherine    10301          0                0         0
# 308          Zamora, Jennifer   10010          0                0         0
# 309               Zhou, Julia   10043          0                0         0
# 310             Zima, Colleen   10271          0                4         0
#
# ...

# %% [markdown]
# apply function on series

# %%
df["Names"].apply(len)
# Out:
# 0      19
# 1      24
# 2      17
# 3      12
# 4      16
#        ..
# 306    14
# 307    18
# 308    16
# 309    11
# 310    13
# Name: Names, Length: 311, dtype: int64

# %% [markdown]
# ###### Add-Remove-Rows-Columns on Dataframe

# %%
df["ImportantInfo"]= df["Position"]+ " ,"+ df["Names"]
df
# Out:
#                         Names  MaimID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K   10026          0                0         1
# 1    Ait Sidi, Karthikeyan      10084          1                1         1
# 2           Akinkuolie, Sarah   10196          1                1         0
# 3                Alagbe,Trina   10088          1                1         0
# 4            Anderson, Carol    10069          0                2         0
# ..                        ...     ...        ...              ...       ...
# 306            Woodson, Jason   10135          0                0         1
# 307        Ybarra, Catherine    10301          0                0         0
# 308          Zamora, Jennifer   10010          0                0         0
# 309               Zhou, Julia   10043          0                0         0
# 310             Zima, Colleen   10271          0                4         0
#
# ...

# %%
df.drop("ImportantInfo", axis=1)
# Out:
#                         Names  MaimID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K   10026          0                0         1
# 1    Ait Sidi, Karthikeyan      10084          1                1         1
# 2           Akinkuolie, Sarah   10196          1                1         0
# 3                Alagbe,Trina   10088          1                1         0
# 4            Anderson, Carol    10069          0                2         0
# ..                        ...     ...        ...              ...       ...
# 306            Woodson, Jason   10135          0                0         1
# 307        Ybarra, Catherine    10301          0                0         0
# 308          Zamora, Jennifer   10010          0                0         0
# 309               Zhou, Julia   10043          0                0         0
# 310             Zima, Colleen   10271          0                4         0
#
# ...

# %% [markdown]
# ##### Sorting Data

# %%
df["Salary"].nsmallest(10)
# Out:
# 310    45046
# 140    45069
# 231    45115
# 176    45395
# 152    45433
# 216    45998
# 159    46120
# 74     46335
# 247    46428
# 226    46430
# Name: Salary, dtype: int64

# %%
df.nlargest(10, 'Salary')
# Out:
#                 Names  MaimID  MarriedID  MaritalStatusID  GenderID  \
# 150       King, Janet   10089          1                1         0
# 308  Zamora, Jennifer   10010          0                0         0
# 131   Houlihan, Debra   10272          1                1         0
# 96        Foss, Jason   10015          0                0         1
# 55     Corleone, Vito   10019          0                0         1
# 190     Monroe, Peter   10288          1                1         1
# 240      Roper, Katie   10086          0                0         0
# 244     Ruiz, Ricardo   10222          0                2         1
# 243        Roup,Simon   10198          0                0         1
# 76      Dougall, Eric   10028          0                0         1
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 150            1       2            3                       0  250000      0
# ...

# %%
df.sort_values("Salary")
# Out:
#                    Names  MaimID  MarriedID  MaritalStatusID  GenderID  \
# 310        Zima, Colleen   10271          0                4         0
# 140     Jacobi, Hannah     10236          0                2         0
# 231       Rhoads, Thomas   10058          0                2         1
# 176    Mahoney, Lauren     10219          0                0         0
# 152  Kirill, Alexandra     10170          1                1         0
# ..                   ...     ...        ...              ...       ...
# 55        Corleone, Vito   10019          0                0         1
# 96           Foss, Jason   10015          0                0         1
# 131      Houlihan, Debra   10272          1                1         0
# 308     Zamora, Jennifer   10010          0                0         0
# 150          King, Janet   10089          1                1         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# ...

# %% [markdown]
# ##### Grouping and Aggregating

# %%
RecruitmentSource_grp = df.groupby(["RecruitmentSource"])
RecruitmentSource_grp

# %%
RecruitmentSource_grp.get_group("LinkedIn")
# Out:
#                    Names  MaimID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi, Wilson  K   10026          0                0         1
# 2      Akinkuolie, Sarah   10196          1                1         0
# 5      Anderson, Linda     10002          0                0         0
# 6        Andreola, Colby   10194          0                0         0
# 19         Becker, Scott   10277          0                0         1
# ..                   ...     ...        ...              ...       ...
# 300      Whittier, Scott   10072          0                0         1
# 304   Winthrop, Jordan     10033          0                0         1
# 305        Wolk, Hang  T   10174          0                0         0
# 306       Woodson, Jason   10135          0                0         1
# 310        Zima, Colleen   10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# ...

# %%
filt=df["RecruitmentSource"]=="LinkedIn"
df.loc[filt]["Department"].value_counts()
# Out:
# Production              61
# IT/IS                   11
# Software Engineering     2
# Sales                    2
# Name: Department, dtype: int64

# %%
df.loc[filt]["Department"].value_counts(normalize=True)
# Out:
# Production              0.802632
# IT/IS                   0.144737
# Software Engineering    0.026316
# Sales                   0.026316
# Name: Department, dtype: float64

# %%
RecruitmentSource_grp["Absences"].agg(["mean", "median"])
# Out:
#                               mean  median
# RecruitmentSource
# CareerBuilder            10.304348     9.0
# Diversity Job Fair       11.379310    12.0
# Employee Referral        10.290323     9.0
# Google Search            10.367347    10.0
# Indeed                    9.977011    10.0
# LinkedIn                 10.302632    11.0
# On-line Web application   1.000000     1.0
# Other                     9.000000     9.0
# Website                   9.230769     8.0

# %%
df.loc[filt]["Department"].str.contains("Software Engineering").sum()
# Out:
# 2

# %%
RecruitmentSource_grp["Department"].apply(lambda x: x.str.contains("Software Engineering").sum())
# Out:
# RecruitmentSource
# CareerBuilder              1
# Diversity Job Fair         3
# Employee Referral          0
# Google Search              2
# Indeed                     3
# LinkedIn                   2
# On-line Web application    0
# Other                      0
# Website                    0
# Name: Department, dtype: int64
